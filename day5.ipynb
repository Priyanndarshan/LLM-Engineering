# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  'blog/inference-providers-nebius-novita-hyperbolic',
#  '/spaces',
#  '/models',
#  '/perplexity-ai/r1-1776',
#  '/deepseek-ai/DeepSeek-R1',
#  '/microsoft/OmniParser-v2.0',
#  '/stepfun-ai/Step-Audio-Chat',
#  '/stepfun-ai/stepvideo-t2v',
#  '/models',
#  '/spaces/nanotron/ultrascale-playbook',
#  '/spaces/lllyasviel/LuminaBrush',
#  '/spaces/microsoft/OmniParser-v2',
#  '/spaces/black-forest-labs/FLUX.1-dev',
#  '/spaces/m-ric/open_Deep-Research',
#  '/spaces',
#  '/datasets/Congliu/Chinese-DeepSeek-R1-Distill-data-110k',
#  '/datasets/open-r1/OpenR1-Math-220k',
#  '/datasets/facebook/natural_reasoning',
#  '/datasets/open-thoughts/OpenThoughts-114k',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'homepage', 'url': 'https://huggingface.co'},
#   {'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community discussions', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'LinkedIn', 'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'GitHub', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter', 'url': 'https://twitter.com/huggingface'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Welcome Hyperbolic, Nebius AI Studio, and Novita on the Hub 🔥
# Welcome Fireworks.ai on the Hub 🎆
# Welcome to Inference Providers on the Hub 🔥
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# perplexity-ai/r1-1776
# Updated
# 2 days ago
# •
# 6.44k
# •
# 1.28k
# deepseek-ai/DeepSeek-R1
# Updated
# 12 days ago
# •
# 4.35M
# •
# 9.84k
# microsoft/OmniParser-v2.0
# Updated
# 3 days ago
# •
# 3.58k
# •
# 790
# stepfun-ai/Step-Audio-Chat
# Updated
# 4 days ago
# •
# 544
# •
# 326
# stepfun-ai/stepvideo-t2v
# Updated
# 2 days ago
# •
# 800
# •
# 273
# Browse 1M+ models
# Spaces
# Running
# 1.11k
# 1.11k
# The Ultra-Scale Playbook
# 🌌
# The ultimate guide to training LLM on large GPU Clusters
# Running
# on
# Zero
# 623
# 623
# LuminaBrush
# 📈
# Execute custom code
# Running
# on
# Zero
# 250
# 250
# OmniParser V2
# 🏢
# OmniParser, turn your LLM into GUI agent
# Running
# on
# Zero
# 7.31k
# 7.31k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# Running
# on
# CPU Upgrade
# 505
# 505
# Open Deep-Research
# 🏆
# OpenAI's Deep Research, but open
# Browse 400k+ applications
# Datasets
# Congliu/Chinese-DeepSeek-R1-Distill-data-110k
# Updated
# about 11 hours ago
# •
# 1.61k
# •
# 292
# open-r1/OpenR1-Math-220k
# Updated
# 3 days ago
# •
# 16.5k
# •
# 386
# facebook/natural_reasoning
# Updated
# about 8 hours ago
# •
# 473
# •
# 111
# open-thoughts/OpenThoughts-114k
# Updated
# 1 day ago
# •
# 97.4k
# •
# 570
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 11.7k
# •
# 7.55k
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 389 models
# •
# 2.37k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.65k followers
# Amazon Web Services
# company
# •
# 20 models
# •
# 2.75k followers
# Google
# company
# •
# 959 models
# •
# 7.99k followers
# Intel
# company
# •
# 218 models
# •
# 2.27k followers
# Microsoft
# company
# •
# 356 models
# •
# 8.92k followers
# Grammarly
# company
# •
# 10 models
# •
# 126 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 240 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 139,890
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 27,616
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,118
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,354
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,395
# Fast tokenizers optimized for research & production
# TRL
# 11,867
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,010
# State-of-the-art ML running directly in your browser
# smolagents
# 11,374
# Smol library to build great agents in Python
# PEFT
# 17,415
# Parameter-efficient finetuning for large language models
# Datasets
# 19,660
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,783
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,361
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 21,254
# AI & ML interests
# The AI community building the future.
# Recent Activity
# lysandre
# updated
# a dataset
# about 4 hours ago
# huggingface/transformers-metadata
# qubvel-hf
# updated
# a dataset
# about 5 hours ago
# huggingface/documentation-images
# ariG23498
# updated
# a dataset
# about 10 hours ago
# huggingface/documentation-images
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 34
# Team members
# 210
# +176
# +163
# +142
# +132
# +112
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 288k
# •
# 38
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 15.9M
# •
# •
# 621
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 943k
# •
# •
# 168
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 7.71M
# •
# •
# 691
# spaces
# 23
# Sort:
# 		Recently updated
# pinned
# Running
# 64
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 93
# Inference Playground
# 🔋
# Generate responses to chat messages
# huggingface
# 1 day ago
# Running
# 528
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Running
# 211
# paper-central
# ⚡
# Explore and manage research papers
# huggingface
# Dec 13, 2024
# Running
# on
# TPU v5e
# 8
# Keras Chatbot Battle
# 💬
# Interact with multiple chatbots simultaneously
# huggingface
# Dec 5, 2024
# Running
# 104
# Modelcard Creator
# ⚡
# Create and upload a Hugging Face model card
# huggingface
# Oct 26, 2024
# Expand 23
# 							spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Dec 9, 2024
# •
# 35
# •
# 1
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 3.89k
# •
# •
# 56
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 64
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 53.6k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 285
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 24.8k
# •
# 5
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 3.61k
# •
# 18
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 69
# •
# 4
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 35k
# •
# 76
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand 16
# 							models
# datasets
# 38
# Sort:
# 		Recently updated
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# about 4 hours ago
# •
# 1.57k
# •
# 3.03k
# •
# 16
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 5 hours ago
# •
# 50
# •
# 4.4M
# •
# 49
# huggingface/gemini-results-2025-02-20
# Viewer
# •
# Updated
# about 11 hours ago
# •
# 29
# huggingface/gemini-results-2025-02-19
# Viewer
# •
# Updated
# 1 day ago
# •
# 30
# •
# 3
# huggingface/gemini-results-2025-02-18
# Viewer
# •
# Updated
# 2 days ago
# •
# 38
# •
# 13
# huggingface/gemini-results-2025-02-17
# Viewer
# •
# Updated
# 3 days ago
# •
# 23
# •
# 24
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# 4 days ago
# •
# 130
# •
# 19
# huggingface/gemini-results-new-cs-papers-2025-02-11-0-100-updated
# Viewer
# •
# Updated
# 4 days ago
# •
# 100
# •
# 18
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 6 days ago
# •
# 66
# •
# 465
# •
# 5
# huggingface/wiki_dpr
# Updated
# 16 days ago
# •
# 81
# Expand 38
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# company page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 285 models
# •
# 16.2k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 280 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 181 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 240 followers
# Xsolla
# Enterprise
# company
# •
# 97 followers
# Fidelity Investments
# Enterprise
# company
# •
# 124 followers
# Mistral AI_
# Enterprise
# company
# •
# 23 models
# •
# 5.5k followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.21k followers
# Chegg Inc
# Enterprise
# company
# •
# 82 followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 59 followers
# creditkarma
# Enterprise
# company
# •
# 47 followers
# Liberty Mutual
# Enterprise
# company
# •
# 43 followers
# StepFun
# Enterprise
# company
# •
# 7 models
# •
# 571 followers
# Ekimetrics
# Enterprise
# company
# •
# 52 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 27.8k followers
# AMD
# Enterprise
# company
# •
# 88 models
# •
# 1.31k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.65k followers
# Arm
# Enterprise
# company
# •
# 140 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 99 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 392 followers
# Procter & Gamble
# Enterprise
# company
# •
# 69 followers
# IBM Granite
# Enterprise
# company
# •
# 73 models
# •
# 1.06k followers
# Novo Nordisk
# Enterprise
# company
# •
# 50 followers
# Stability AI
# Enterprise
# company
# •
# 99 models
# •
# 16.4k followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 537 followers
# Widn AI
# Enterprise
# company
# •
# 39 followers
# BCG X
# Enterprise
# company
# •
# 33 followers
# Adyen
# Enterprise
# company
# •
# 45 followers
# Shopify
# Enterprise
# company
# •
# 406 followers
# Snowflake
# Enterprise
# company
# •
# 14 models
# •
# 429 followers
# Together
# Enterprise
# company
# •
# 31 models
# •
# 520 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 174 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 124 followers
# Jusbrasil
# Enterprise
# company
# •
# 80 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 122 followers
# Aledade Inc
# Enterprise
# company
# •
# 60 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 60 followers
# Arcee AI
# Enterprise
# company
# •
# 153 models
# •
# 415 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 47 followers
# HiddenLayer
# Enterprise
# company
# •
# 54 followers
# Kakao Corp.
# Enterprise
# company
# •
# 49 followers
# NewMindAI
# Enterprise
# company
# •
# 33 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# SigLIP 2: A better multilingual vision language encoder
# By
# ariG23498
# February 21, 2025
# •
# 26
# Community Articles
# view all
# Open Source AI Agents | Github/Repo List | [2025]
# By
# tegridydev
# •
# about 5 hours ago
# •
# 2
# Topic 28: What is Mixture-of-Mamba?
# By
# Kseniase
# and 1 other
# •
# about 21 hours ago
# •
# 2
# Mimicking Consciousness in LLMs: Ascending the Dimensions of Thought with Recurrent Processing
# By
# KnutJaegersberg
# •
# 1 day ago
# 结合Deepseek代码探讨MLA的改进及收益
# By
# Junrulu
# •
# 1 day ago
# •
# 2
# 大模型偏好优化技术：DPO及其变种
# By
# Junrulu
# •
# 1 day ago
# •
# 3
# Grok 3 ai : Best AI model now!
# By
# LLMhacker
# •
# 2 days ago
# •
# 4
# Argunauts Training Phase II: Selfplay Finetuning Line-By-Line
# By
# ggbetz
# •
# 2 days ago
# •
# 2
# Synthetic Face Embeddings: Research Notes and Methodology
# By
# jadechip
# and 1 other
# •
# 2 days ago
# •
# 1
# How to use Sentient’s Dobby-70B
# By
# chrisaubin
# •
# 2 days ago
# Mahjong: Where Grandmas Beat The Best LLMs
# By
# sileixu
# •
# 3 days ago
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# 3 days ago
# •
# 18
# Argunauts Training Phase I: Continual Pretraining on Synthetic Data
# By
# ggbetz
# •
# 3 days ago
# Best AI Setups for Multi-Agent Workflows in KaibanJS
# By
# darielnoel
# •
# 3 days ago
# 🌁#88: Can DeepSeek Inspire Global Collaboration?
# By
# Kseniase
# •
# 4 days ago
# •
# 3
# Adapter l’intelligence artificielle au créole
# By
# hugohow
# •
# 4 days ago
# •
# 1
# Open-sourcing the Plain English to SQL Pipeline
# By
# ZennyKenny
# •
# 4 days ago
# •
# 1
# Fine-tuning SmolLM with Group Relative Policy Optimization (GRPO) by following the Methodologies
# By
# prithivMLmods
# •
# 4 days ago
# •
# 15
# Nexus Shift: AI Generated Short Story
# By
# Duskfallcrew
# •
# 4 days ago
# WTF is Fine-Tuning? (intro4devs) | [2025]
# By
# tegridydev
# •
# 5 days ago
# •
# 5
# 🦸🏻#10: Does Present-Day GenAI Actually Reason?
# By
# Kseniase
# •
# 6 days ago
# •
# 5
# SmolVLM2: Bringing Video Understanding to Every Device
# By
# orrzohar
# February 20, 2025
# guest
# •
# 91
# PaliGemma 2 Mix - New Instruction Vision Language Models by Google
# By
# ariG23498
# February 19, 2025
# •
# 49
# Introducing Three New Serverless Inference Providers: Hyperbolic, Nebius AI Studio, and Novita 🔥
# By
# reach-vb
# February 18, 2025
# •
# 81
# Welcome Fireworks.ai on the Hub 🎆
# By
# julien-c
# February 14, 2025
# •
# 50
# Fixing Open LLM Leaderboard with Math-Verify
# By
# hynky
# February 14, 2025
# •
# 24
# 1 Billion Classifications
# By
# derek-thomas
# February 13, 2025
# guest
# •
# 38
# From Chunks to Blocks: Accelerating Uploads and Downloads on the Hub
# By
# jsulz
# February 12, 2025
# •
# 48
# Build awesome datasets for video generation
# By
# hlky
# February 12, 2025
# •
# 25
# The Open Arabic LLM Leaderboard 2
# By
# alielfilali01
# February 10, 2025
# guest
# •
# 25
# Open-source DeepResearch – Freeing our search agents
# By
# m-ric
# February 4, 2025
# •
# 1.06k
# π0 and π0-FAST: Vision-Language-Action Models for General Robot Control
# By
# danaaubakirova
# February 4, 2025
# •
# 106
# DABStep: Data Agent Benchmark for Multi-step Reasoning
# By
# eggie5
# February 4, 2025
# guest
# •
# 47
# The AI tools for Art Newsletter - Issue 1
# By
# linoyts
# January 31, 2025
# •
# 63
# How to deploy and fine-tune DeepSeek models on AWS
# By
# pagezyhf
# January 30, 2025
# •
# 45
# Previous
# 1
# 2
# 3
# ...
# 39
# Next
# Community Articles
# view all
# Open Source AI Agents | Github/Repo List | [2025]
# By
# tegridydev
# •
# about 5 hours ago
# •
# 2
# Topic 28: What is Mixture-of-Mamba?
# By
# Kseniase
# and 1 other
# •
# about 21 hours ago
# •
# 2
# Mimicking Consciousness in LLMs: Ascending the Dimensions of Thought with Recurrent Processing
# By
# KnutJaegersberg
# •
# 1 day ago
# 结合Deepseek代码探讨MLA的改进及收益
# By
# Junrulu
# •
# 1 day ago
# •
# 2
# 大模型偏好优化技术：DPO及其变种
# By
# Junrulu
# •
# 1 day ago
# •
# 3
# Grok 3 ai : Best AI model now!
# By
# LLMhacker
# •
# 2 days ago
# •
# 4
# Argunauts Training Phase II: Selfplay Finetuning Line-By-Line
# By
# ggbetz
# •
# 2 days ago
# •
# 2
# Synthetic Face Embeddings: Research Notes and Methodology
# By
# jadechip
# and 1 other
# •
# 2 days ago
# •
# 1
# How to use Sentient’s Dobby-70B
# By
# chrisaubin
# •
# 2 days ago
# Mahjong: Where Grandmas Beat The Best LLMs
# By
# sileixu
# •
# 3 days ago
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# 3 days ago
# •
# 18
# Argunauts Training Phase I: Continual Pretraining on Synthetic Data
# By
# ggbetz
# •
# 3 days ago
# Best AI Setups for Multi-Agent Workflows in KaibanJS
# By
# darielnoel
# •
# 3 days ago
# 🌁#88: Can DeepSeek Inspire Global Collaboration?
# By
# Kseniase
# •
# 4 days ago
# •
# 3
# Adapter l’intelligence artificielle au créole
# By
# hugohow
# •
# 4 days ago
# •
# 1
# Open-sourcing the Plain English to SQL Pipeline
# By
# ZennyKenny
# •
# 4 days ago
# •
# 1
# Fine-tuning SmolLM with Group Relative Policy Optimization (GRPO) by following the Methodologies
# By
# prithivMLmods
# •
# 4 days ago
# •
# 15
# Nexus Shift: AI Generated Short Story
# By
# Duskfallcrew
# •
# 4 days ago
# WTF is Fine-Tuning? (intro4devs) | [2025]
# By
# tegridydev
# •
# 5 days ago
# •
# 5
# 🦸🏻#10: Does Present-Day GenAI Actually Reason?
# By
# Kseniase
# •
# 6 days ago
# •
# 5
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# How to help in translating?
# Site Feedback
# 1
# 2
# February 21, 2025
# How to access /tmp files
# Beginners
# 1
# 5
# February 21, 2025
# 504 Gateway Time-out when uploading large dataset to enterprise organization
# 🤗Datasets
# 1
# 2
# February 21, 2025
# /tmp files directory
# Beginners
# 0
# 2
# February 21, 2025
# Paper author is incorrect
# Beginners
# 2
# 11
# February 21, 2025
# Agent wont respond
# Beginners
# 1
# 6
# February 21, 2025
# Agents Course Certification
# Spaces
# 8
# 112
# February 19, 2025
# kohya_SS (Output Interpretation)
# Intermediate
# 8
# 11
# February 21, 2025
# Freeze Rt-detr backbone when fine tuning on custom dataset
# 🤗Transformers
# 2
# 5
# February 21, 2025
# ImportError: cannot import name 'load_dataset' from 'datasets' (unknown location)
# Beginners
# 12
# 39148
# February 21, 2025
# Gradio Private space
# Spaces
# 2
# 91
# February 21, 2025
# Text Classification without context
# Beginners
# 3
# 23
# February 21, 2025
# Where does the Transformers do the target text shifting in causal LM?
# Beginners
# 4
# 4202
# February 21, 2025
# Should 24GB of VRAM be able to fine tune a 1B model?
# Beginners
# 6
# 91
# February 21, 2025
# Loading in Float32 vs Float16 has very different speed
# 🤗Transformers
# 1
# 10
# February 20, 2025
# File with .model extension
# Beginners
# 2
# 6
# February 20, 2025
# Cuda out of memory during evaluation but training is fine
# 🤗Transformers
# 12
# 16745
# February 20, 2025
# Can we use LLM model method or GenAI for lots of tabular information and get the insight of that
# 🤗Transformers
# 1
# 4
# February 21, 2025
# Potential bug in the rt-detr v2 fine tune script
# 🤗Transformers
# 1
# 58
# February 20, 2025
# Request failed: 500
# Beginners
# 5
# 98
# February 21, 2025
# Use t5-small ft a English to German Bidirectional translation model
# 🤗Transformers
# 3
# 4
# February 21, 2025
# Enterprise Analytics not working
# Site Feedback
# 3
# 16
# February 19, 2025
# Evaluating my own model
# Intermediate
# 6
# 18
# February 21, 2025
# What is the most suitable padding strategy for PPOTrainer?
# 🤗Transformers
# 1
# 7
# February 20, 2025
# Why does chunked dataset training give different results compared to full-batch training in my Siren model?
# Community Calls
# 1
# 8
# February 20, 2025
# FastAPI Routing Issue in Hugging Face Spaces
# Spaces
# 3
# 1470
# February 20, 2025
# How to file or Env Chagne?
# 🤗AutoTrain
# 2
# 15
# February 20, 2025
# Non-Coder Training Question
# Beginners
# 5
# 319
# February 20, 2025
# RT-DETR with MobileNet
# Models
# 1
# 8
# February 20, 2025
# Fine-tuning queries
# Beginners
# 0
# 12
# February 20, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# Twitter page
# Webpage Title:
# x.com
# Webpage Contents:
#
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 498 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian@🤗 | Championing Open Science & Machine Learning
# 20h
# Report this post
# Just hacked together a way to log TRL
# #GRPO
# training completions directly to a
# Hugging Face
# datasets repo.
#
# This allows you to:
# - Track rewards from multiple reward functions
# - Treat completions and rewards as a proper dataset for EDA
# - Share results for open science 🤓
#
# The current implementation is super hacky but only requires two extra parameters:
#
# ```
# training_args = GRPOConfig(
#     # other configs...
#     log_completions=True,
#     log_completions_hub_repo='your-username/repo-name'
# )
# ```
#
# Example completions log dataset:
# https://lnkd.in/eF2MKhXw
# Notebook:
# https://lnkd.in/eYRuTxPR
# I'm curious if other people find this interesting or useful for RLHF/GRPO research or if I'm the only weirdo who finds starting at GRPO completions interesting or useful.
# 27
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Miquel Àngel Farré
# ML @ Hugging Face
# 23h
# Report this post
# We've put video AI right on your iPhone! No cloud, no servers - everything happens right on your device 🤩
# 🎉 We are launching SmolVLM2 today!!
#
# This is what you can find in the release:
# - A 2.2B model that achieves top scores on Video-MME (the toughest video benchmark out there) in the 2B category. If that is not enough: it's way better at vision tasks than our previous SmolVLM. And yes, it runs on Google Colab! 🚀
# The two smallest video models ever:
#
# - A 500M model - That's how we got it running on phones! Want to build and test with us? Fill the form in our blog post and we will keep you in the loop.
#
# - A 256M model - because we love pushing boundaries perfect for experimenting and seeing just how far we can push this tech 🔬
#
# Oh, and we're working with the
# VideoLAN
# team to bring this to VLC! Imagine just asking your media player to find specific moments in your videos...
# We packed our blogpost with demos and code snippets. Find the link in the first comment.
# …more
# 982
# 65 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 1d
# Report this post
# We just shipped LoRA support in Lumina2 along with a new fine-tuning script as an example to follow 🔥
#
# Lumina2, being an Apache-2.0 model, holds tremendous promise for further widespread adaptation. I think the model packs quite a bit of performance for its size.
#
# I found its system prompting abilities to be particularly intriguing. For example, in the attached image, different system prompts for different environment settings have an impact without diluting the actual style of the LoRA.
#
# Get started with fine-tuning with this guide:
# https://lnkd.in/g3dbXDsw
# 166
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 56,612 followers
# 1d
# Report this post
# Many people find themselves exploring a Gradio app, often without even realizing it! 👀
# 45
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 890,103 followers
# 1d
# Report this post
# A highly requested feature from Gradio developers 🔥 is on its way in upcoming releases.
# Gradio
# 56,612 followers
# 1d
# 🚀 Performance Breakthrough: Instant UI Updates
# No server roundtrips; UI updates within your browser.
#
# Watch the video to understand Before vs After with a simple Todo app.
#
# 🤩 Key Benefits:
# - Instant component updates
# - Better user experience
# - No additional Javascript to be written
#
# 🚀 Perfect for:
# - Dynamic UI elements
# - Real-time updates
#
# This maintains Gradio's Python-first approach and addresses one of the most requested features from our developer community. Coming to you in our next release 🥳
# 23
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1d
# Report this post
# Google
# just released PaliGemma 2 Mix: new versatile instruction vision language models 🔥 learn more in comments 💬
#
# > Three new models: 3B, 10B, 28B with res 224, 448 💙
# > Can do vision language tasks with open-ended prompts, understand documents, and segment or detect anything 🤯
# …more
# 952
# 27 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 56,612 followers
# 2d
# Report this post
# Every minute of boilerplate code reduces time for innovation
# That's why we've built Gradio Sketch🤯
#
# Visually design your AI interfaces:
# ↓ Add components
# ↓ Configure settings
# ↓ Preview in real-time
# ↓ Get production-ready code in seconds
#
# The future of AI app development should be visual!
# And it starts with: `gradio sketch testdotpy`
#
# Who else is tired of writing repetitive interface code for their AI apps?
# …more
# 303
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Joffrey THOMAS
# Machine Learning Engineer - Hugging Face 🤗
# 2d
# Edited
# Report this post
# 🚀 Bonus Unit Alert! 🚀
# 𝐅𝐢𝐧𝐞-𝐭𝐮𝐧𝐢𝐧𝐠 𝐲𝐨𝐮𝐫 𝐦𝐨𝐝𝐞𝐥 𝐟𝐨𝐫 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧-𝐂𝐚𝐥𝐥𝐢𝐧𝐠 𝐢𝐬 𝐨𝐮𝐭 !
#
# 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧-𝐂𝐚𝐥𝐥𝐢𝐧𝐠 has been introduced by OpenAI in GPT-4. It's a training technique that allocate new special tokens and messages roles to your model.
#
# 🔗:
# https://lnkd.in/ebsRZqNE
# What you'll learn :
# 1️⃣ 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧-𝐜𝐚𝐥𝐥𝐢𝐧𝐠 : What is it, how does it modify the conversations with your AI.
# 2️⃣ 𝐇𝐨𝐰 𝐭𝐨 𝐦𝐚𝐤𝐞 𝐲𝐨𝐮𝐫 𝐦𝐨𝐝𝐞𝐥 "𝐭𝐡𝐢𝐧𝐤" : The powerful recipe behind the success of DeepSeek AI.
# 3️⃣ 𝐅𝐢𝐧𝐞-𝐓𝐮𝐧𝐢𝐧𝐠 (𝐒𝐅𝐓): Learn LoRA, a powerful technique to fine-tune a model through adapters for a fraction of the cost of the full fine-tuning.
# 752
# 20 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 3d
# Edited
# Report this post
# Inference-time scaling meets Flux.1-Dev (and others) 🔥
#
# Presenting a simple re-implementation of "Inference-time scaling diffusion models beyond denoising steps" by
# Willis (Nanye) Ma
# et al.
#
# I did the simplest random search strategy, but results can potentially be improved with better-guided search methods.
#
# Supports Gemini 2 Flash & Qwen2.5 as verifiers for "LLMGrading" 🤗
#
# The steps are simple:
#
# For each round:
# 1> Starting by sampling 2 starting noises with different seeds.
# 2> Score the generations w.r.t a metric.
# 3> Obtain the best generation from the current round.
#
# If you have more compute budget, go to the next search round. Scale the noise pool (2 ** search_round) and repeat 1 - 3.
#
# This constitutes the random search method as done in the paper by
# Google DeepMind
# .
#
# Code, more results, and a bunch of other stuff are in the repository. Check it out here:
# https://lnkd.in/gPRDz7KB
# 🤗
#
# Thanks to
# Willis
# for all the help in getting this shipped!
# 166
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 3d
# Report this post
# NEW COURSE! We’re cooking hard on
# Hugging Face
# courses, and it’s not just agents. The NLP course is getting the same treatment with a new chapter on Supervised Fine-Tuning!
#
# 👉 Follow to get more updates
# https://lnkd.in/eXZPaJZT
# The new SFT chapter will guide you through these topics:
# 1️⃣ Chat Templates: Master the art of structuring AI conversations for consistent and helpful responses.
# 2️⃣ Supervised Fine-Tuning (SFT): Learn the core techniques to adapt pre-trained models to your specific outputs.
# 3️⃣ Low Rank Adaptation (LoRA): Discover efficient fine-tuning methods that save memory and resources.
# 4️⃣ Evaluation: Measure your model's performance and ensure top-notch results.
#
# This is the first update in a series, so follow along if you’re upskilling in AI.
# 1,768
# 36 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# Perplexity
# Software Development
# San Francisco, California
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 7 total rounds
# Last Round
# Series D
# Feb 16, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# "You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nNEW\nWelcome Hyperbolic, Nebius AI Studio, and Novita on the Hub 🔥\nWelcome Fireworks.ai on the Hub 🎆\nWelcome to Inference Providers on the Hub 🔥\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nperplexity-ai/r1-1776\nUpdated\n2 days ago\n•\n6.44k\n•\n1.28k\ndeepseek-ai/DeepSeek-R1\nUpdated\n12 days ago\n•\n4.35M\n•\n9.84k\nmicrosoft/OmniParser-v2.0\nUpdated\n3 days ago\n•\n3.58k\n•\n790\nstepfun-ai/Step-Audio-Chat\nUpdated\n4 days ago\n•\n544\n•\n326\nstepfun-ai/stepvideo-t2v\nUpdated\n2 days ago\n•\n800\n•\n273\nBrowse 1M+ models\nSpaces\nRunning\n1.11k\n1.11k\nThe Ultra-Scale Playbook\n🌌\nThe ultimate guide to training LLM on large GPU Clusters\nRunning\non\nZero\n623\n623\nLuminaBrush\n📈\nExecute custom code\nRunning\non\nZero\n250\n250\nOmniParser V2\n🏢\nOmniParser, turn your LLM into GUI agent\nRunning\non\nZero\n7.31k\n7.31k\nFLUX.1 [dev]\n🖥\nGenerate images from text prompts\nRunning\non\nCPU Upgrade\n505\n505\nOpen Deep-Research\n🏆\nOpenAI's Deep Research, but open\nBrowse 400k+ applications\nDatasets\nCongliu/Chinese-DeepSeek-R1-Distill-data-110k\nUpdated\nabout 11 hours ago\n•\n1.61k\n•\n292\nopen-r1/OpenR1-Math-220k\nUpdated\n3 days ago\n•\n16.5k\n•\n386\nfacebook/natural_reasoning\nUpdated\nabout 8 hours ago\n•\n473\n•\n111\nopen-thoughts/OpenThoughts-114k\nUpdated\n1 day ago\n•\n97.4k\n•\n570\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n11.7k\n•\n7.55k\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n389 models\n•\n2.37k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.06k models\n•\n4.65k followers\nAmazon Web Services\ncompany\n•\n20 models\n•\n2.75k followers\nGoogle\ncompany\n•\n959 models\n•\n7.99k followers\nIntel\ncompany\n•\n218 models\n•\n2.27k followers\nMicrosoft\ncompany\n•\n356 models\n•\n8.92k followers\nGrammarly\ncompany\n•\n10 models\n•\n126 followers\nWriter\nEnterprise\ncompany\n•\n17 models\n•\n240 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n139,890\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n27,616\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,118\nSafe way to store/distribute neural network weights\nHub Python Library\n2,354\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,395\nFast tokenizers optimized for research & production\nTRL\n11,867\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,010\nState-of-the-art ML running directly in your browser\nsmolagents\n ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}
# ```markdown
# # Hugging Face Brochure
#
# ## The AI Community Building the Future
# Welcome to **Hugging Face**, a collaborative platform where the machine learning community engages in creating, discovering, and sharing models, datasets, and applications. Our innovative tools and open-source resources empower users to accelerate their artificial intelligence projects.
#
# ### Our Offerings
# - **Models**: Access and share over **1M+ models**, including state-of-the-art solutions for diverse tasks.
# - **Datasets**: Browse through a vast collection of **250k+ datasets** to fuel your projects.
# - **Spaces**: Host and collaborate on applications that seamlessly integrate with our tools.
#
# ## Collaborate and Innovate
# At Hugging Face, we believe in the power of community-driven collaboration. More than **50,000 organizations**, including industry giants like Google, Microsoft, and Amazon Web Services, trust us for their machine learning needs.
#
# ### Our Open Source Tools
# We are laying the groundwork for machine learning with our robust open-source stack, including:
# - **Transformers**: Over **139,890 models** for state-of-the-art ML.
# - **Diffusers**: **27,616** diffusion models that redefine creative AI applications.
# - **Tokenizers**: Efficient solutions optimized for both research and production.
#
# ## Career Opportunities
# Join our vibrant and inclusive culture. At Hugging Face, we prioritize diversity and foster an environment where creativity and innovation thrive. We’re dedicated to offering our team meaningful experiences while delivering impactful solutions. Explore our current job openings on our [Jobs page](https://huggingface.co/jobs).
#
# ### Why Work With Us?
# - Work with leading professionals in AI
# - Engage in meaningful projects
# - Flexible work environment
# - Competitive compensation and benefits
#
# ## Get Involved
# Become part of the growing Hugging Face community! Whether you’re a developer looking to contribute, a researcher seeking cutting-edge models, or a business in need of tailored AI solutions, you’ll find a home at Hugging Face.
#
# ### Explore
# - Models: [Browse Now](https://huggingface.co/models)
# - Datasets: [Browse Now](https://huggingface.co/datasets)
# - Join the discussion in our [Forum](https://huggingface.co/forum)
#
# ## Connect with Us
# Follow us on our social media platforms to stay updated on the latest developments and community news:
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [GitHub](https://github.com/huggingface)
#
# ---
#
# Discover, create, and innovate with *Hugging Face*! Let's build the future together.
# ```

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'docs', 'url': 'https://huggingface.co/docs'}, {'type': 'company social media', 'url': 'https://twitter.com/huggingface'}, {'type': 'company social media', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ### Welcome to Hugging Face
#
# **The AI community building the future!** Hugging Face is at the forefront of advancing machine learning technologies and is dedicated to creating a collaborative platform for researchers and developers alike. Our mission is to democratize AI and make it accessible to everyone.
#
# ---
#
# ## What We Do
#
# - **Models:** Explore over 1 million models, including state-of-the-art solutions in text, image, video, audio, and 3D.
# - **Datasets:** Access and share over 250,000 datasets across a multitude of machine learning tasks.
# - **Spaces:** Host and collaborate on public models, datasets, and applications, running over 1,100 applications in real-time.
# - **Enterprise Solutions:** We offer advanced platforms with security, dedicated support, and enterprise-grade features for organizations of all sizes.
#
# ### Key Features
#
# - **Open-Source Community:** Join a vibrant community contributing to the foundation of machine learning tooling.
# - **Cutting-Edge Technology:** We provide various tools like Transformers, Diffusers, and Tokenizers, ensuring streamlined ML processes.
# - **Accelerated Machine Learning:** Get access to paid compute resources and enterprise solutions starting at competitive pricing.
#
# ---
#
# ## Who We Work With
#
# Hugging Face is trusted by over 50,000 organizations including:
#
# - Amazon Web Services
# - Microsoft
# - Google
# - Meta
# - Intel
#
# Join industry leaders who leverage our platform to enhance their AI capabilities.
#
# ---
#
# ## Company Culture
#
# At Hugging Face, we prioritize collaboration, creativity, and community. We believe in empowering our team and fostering an inclusive environment where everyone can contribute to the evolving field of AI. Our work culture encourages continuous learning, experimentation, and sharing knowledge.
#
# ---
#
# ## Careers at Hugging Face
#
# We’re always looking for passionate and innovative individuals to join our team. Available opportunities span engineering, research, marketing, and support roles.
#
# Join us in shaping the future of AI!
#
# - Visit our Jobs page for openings: [Hugging Face Careers](https://huggingface.co/jobs)
#
# ---
#
# ## Connect With Us
#
# Stay updated with our latest innovations and community activities.
#
# - **Follow us on GitHub, Twitter, LinkedIn, and Discord**
# - Collaborate and contribute to community posts and discussions.
#
# ### Let's shape the future of AI together!
#
# ---
#
# For more information, visit our website: [Hugging Face](https://huggingface.co) and explore the endless possibilities in the realm of machine learning.

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face: The AI Community Building the Future
#
# ## Who We Are
# Hugging Face is a leading platform for machine learning and artificial intelligence that fosters collaboration among developers, researchers, and organizations. Designed as a community-first platform, Hugging Face serves as a hub where individuals and enterprises can create, discover, and collaborate on machine learning models, datasets, and applications. Our mission is to democratize AI technology and make it more accessible and usable for everyone.
#
# ## Our Offerings
# At Hugging Face, we provide a comprehensive suite of tools and services for the AI community:
# - **Models**: Access to over **1 million models** contributed by users globally, ranging from text generation models to diffusion technologies.
# - **Datasets**: A repository of over **250,000 datasets** suited for various machine learning tasks.
# - **Spaces**: Run apps and collaborate on projects with over **400,000 applications** in an interactive environment.
# - **Enterprise Solutions**: We offer tailored services for organizations, ensuring enterprise-grade security and dedicated support.
#
# ## Our Customers
# We proudly serve more than **50,000 organizations** worldwide, including renowned companies such as:
# - **Amazon Web Services**
# - **Google**
# - **Meta**
# - **Microsoft**
# - **Grammarly**
#
# Our platform is trusted by both enterprises and non-profits alike, enabling them to leverage machine learning in innovative ways.
#
# ## Company Culture
# At Hugging Face, we nurture a collaborative and inclusive culture that encourages creativity and innovation. We believe in the power of community and open-source contributions, creating a space where everyone—from beginners to experts—can thrive. Our team is passionate about pushing the boundaries of what's possible in AI while building tools that empower developers and researchers.
#
# ## Careers at Hugging Face
# Join us in shaping the future of AI! We are always looking for talented individuals to join our diverse team, from engineers and researchers to product managers and marketing professionals. Working at Hugging Face means being part of a mission-driven team that values growth, learning, and the sharing of knowledge. Explore our current job openings [here](#).
#
# ## Get Involved Today!
# Become a part of the Hugging Face community. Whether you're a developer looking to upload models, a researcher seeking datasets or an enterprise looking for powerful AI solutions, Hugging Face has something for you. Sign up today and start building the future of AI together with us!
#
# [Explore Hugging Face](#) | [Contact Us](#) | [Join Our Community](#)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 2 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
